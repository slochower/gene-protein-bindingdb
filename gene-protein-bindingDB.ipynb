# %% [markdown]
# # Analysis of SI Table 6 for genes overexpressed in cancer
#
# **Genes overexpressed in different human solid cancers exhibit different tissue-specific expression profiles**

# %%
# %load_ext blackcellmagic
from glob import glob as glob
from io import StringIO
import os as os

import pandas as pd
import urllib
import json

# %% [markdown]
# To make things easier, I'm going to split Table 6 into separate tables for each type of cancer and then save as a `csv`.

# %%
file_list = glob("*.csv")

# %%
file_list = [i for i in file_list if "ligands" not in i]

# %%
file_list
# Out:
# ['melanoma.csv',
#  'endometrial.csv',
#  'lung.csv',
#  'kidney.csv',
#  'colon.csv',
#  'ovarian.csv',
#  'astrocytoma.csv',
#  'liver.csv',
#  'thyroid.csv',
#  'breast.csv',
#  'glioblastoma.csv',
#  'prostate.csv']

# %% [markdown]
# Now, define the helper functions.

# %%
def get_uniprot(gene):
    """
    Look up gene name in Uniprot.
    """
    # print(f"Looking up {gene} in Uniprot database...")
    url = f"https://www.uniprot.org/uniprot/?query=reviewed:yes+AND+organism:9606+AND+gene_exact:{gene}&format=tab"
    request = urllib.request.Request(url)
    try:
        response = urllib.request.urlopen(request)
    except urllib.error.HTTPError as e:
        # print(f"{gene:10}: HTTP error. Skipping...")
        return None
    page = response.read()
    if page == b"":
        print(f"{gene:10}: Response error. Skipping...")
        return None
    else:
        return pd.read_csv(StringIO(page.decode("utf-8")), sep="\t")

# %%
def get_bindingdb(uniprot):
    """
    Look up uniprot in Binding DB.
    """
    # print(f"Looking up {uniprot} in BindingDB...")
    url = f"http://www.bindingdb.org/axis2/services/BDBService/getLigandsByUniprots?uniprot={uniprot}&cutoff=10&code=0&response=application/json"
    request = urllib.request.Request(url)
    try:
        response = urllib.request.urlopen(request)
    except urllib.error.HTTPError as e:
        # print(f"{uniprot:10}: HTTP error. Skipping...")
        return None

    page = response.read()
    binding_db = json.loads(page.decode("utf-8"))
    if binding_db["getLigandsByUniprotsResponse"] == "":
        return None
    return pd.DataFrame(binding_db["getLigandsByUniprotsResponse"]["affinities"])

# %%
def bindingdb_to_table(table):
    """
    Parse the Binding DB `json` response.
    """

    query = table["query"].values[0]
    affinities = table["affinity"].values
    affinity_types = table["affinity_type"].values
    smiles = table["smile"].values
    monomers = table["monomerid"].values
    return pd.DataFrame(
        {
            "Affinities": affinities,
            "Affinity type": affinity_types,
            "SMILES": smiles,
            "MonomerID": monomers,
            "Query": query,
        }
    )

# %%
def manual_pivot(table):
    """
    The data we get from Binding DB will be in rows.
    But we want each row to basically be a new column, so that gene names are the rows.
    """
    # I had problems working with the built-in `pivot` because the data is non-numeric
    # tmp3 = tmp2.pivot_table(index="Query",
    #                        columns=tmp2.index,
    #                        values=["Affinities"],
    #                        aggfunc=lambda x: ' '.join(x))

    df = pd.DataFrame()
    for row in range(len(table)):
        df[f"Affinity {row:03d}"] = pd.Series(table["Affinities"][row])
        df[f"Type {row:03d}"] = pd.Series(table["Affinity type"][row])
        df[f"SMILES {row:03d}"] = pd.Series(table["SMILES"][row])
        df[f"ID {row:03d}"] = pd.Series(table["MonomerID"][row])
    return df

# %%
def filter_top_three_ligands(table):
    """
    Extract the top three ligands with the tightest binding.
    `errors="coerce"` will ignore entries like >10 or <10.
    """
    table["Affinities"] = pd.to_numeric(table["Affinities"], errors="coerce")
    return table.nsmallest(3, "Affinities")

# %% [markdown]
# Loop over the files, then loop over the genes.
#
# To start I'm just looping over the breast cancer data to see if I can match the one file that Tiqing returned.
#
# First, I map from gene to protein and Uniprot ID. That is stored in the `gene_df` DataFrame.
# Then I use the Uniprot ID to look up data from Binding DB.
#
# Then I join `gene_df` and the Binding DB data.

# %%
for file in file_list:
    if os.path.isfile(os.path.splitext(file)[0] + "-ligands.csv"):
        print(f"Found {os.path.splitext(file)[0] + '-ligands.csv'}, skipping...")
        continue
        
    table = pd.read_csv(file, skiprows=1, names=["Unknown", "Gene", "Overexpression"])
    print(f"Loaded {len(table)} genes from {file}...")
    table = table.drop_duplicates(subset="Gene", keep="first")
    print(f"Found {len(table)} unique genes...")
    df = pd.DataFrame()
    for gene, overexpression in zip(
        table["Gene"].values, table["Overexpression"].values
    ):

        if gene == "---":
            continue
        if "///" in gene:
            gene = gene.split("///")[0]

        gene_table = get_uniprot(gene)
        if gene_table is None:
            print(f"{gene:10} → Unknown. Skipping...")
            continue
        uniprot = gene_table["Entry"].values[0]
        protein = gene_table["Protein names"].values[0]

        gene_df = pd.DataFrame()
        gene_df["Gene"] = pd.Series(gene)
        gene_df["Uniprot"] = pd.Series(uniprot)
        gene_df["Protein"] = pd.Series(protein)
        gene_df["Overexpression"] = pd.Series(overexpression)

        binding_db = get_bindingdb(uniprot)

        if binding_db is not None:
            print(f"{gene:10} → {uniprot:10} → {len(binding_db):4} ligands found...")
            binding_table = bindingdb_to_table(binding_db)
            trimmed_table = filter_top_three_ligands(binding_table)
            binding_pivot = manual_pivot(trimmed_table)

            gene_df = gene_df.join(binding_pivot)
            # Only track the proteins with entries in BindingDB
            df = df.append(gene_df, ignore_index=True)
        else:
            print(f"{gene:10} → {uniprot:10} → {'0':>4} ligands found...")
            pass
    
    if df.empty:
        continue
        
    column_list = df.columns.tolist()
    column_end = [i for i in column_list if "Affinity" in i]
    column_max = int(column_end[-1].split(" ")[1])
    column_order = ["Gene", "Uniprot", "Protein", "Overexpression"]
    for i in range(column_max + 1):
        column_order.append(f"Affinity {i:03d}")
        column_order.append(f"Type {i:03d}")
        column_order.append(f"SMILES {i:03d}")
        column_order.append(f"ID {i:03d}")
    df = df[column_order]
    df.to_csv(os.path.splitext(file)[0] + "-ligands.csv")
# Out:
# Found melanoma-ligands.csv, skipping...
# Found endometrial-ligands.csv, skipping...
# Found lung-ligands.csv, skipping...
# Found kidney-ligands.csv, skipping...
# Loaded 89 genes from colon.csv...
# Found 73 unique genes...
# COL11A1    → P12107     →    0 ligands found...
# KLK10      → O43240     →    0 ligands found...
# CST1       → P01037     →    0 ligands found...
# IL8        → P10145     →    0 ligands found...
# COL10A1    → Q03692     →    0 ligands found...
# INHBA      → P08476     →    0 ligands found...
# CXCL5      → P42830     →    0 ligands found...
# MMP1       → P03956     →    0 ligands found...
# CDH3       → P55291     →    0 ligands found...
# TACSTD2    → P09758     →    0 ligands found...
# CHI3L1     → P36222     →    0 ligands found...
# SPP1       → P10451     →    0 ligands found...
# MMP7       → P09237     →    0 ligands found...
# KRT23      → Q9C075     →    0 ligands found...
# FAP        → Q12884     →    0 ligands found...
# MSLN       → Q13421     →    0 ligands found...
# CXCL3      → P19876     →    0 ligands found...
# KIAA1199   → Q8WUJ3     →    0 ligands found...
# COMP       → P49747     →    0 ligands found...
# CEL        → P19835     →    0 ligands found...
# DUSP4      → Q13115     →    0 ligands found...
# SLCO1B3    → Q9NPD5     →    0 ligands found...
# ADAM12     → O43184     →    0 ligands found...
# MMP3       → P08254     →    0 ligands found...
# SERPINB5   → P36952     →    0 ligands found...
# TDGF1      → P13385     →    0 ligands found...
# ITGBL1     → O95965     →    0 ligands found...
# CXCL1      → P09341     →    0 ligands found...
# COL1A2     → P08123     →    0 ligands found...
# SULF1      → Q8IWU6     →    0 ligands found...
# CXCL11     → O14625     →    0 ligands found...
# LGR5       → O75473     →    0 ligands found...
# TSC        → P55017     →    0 ligands found...
# MMP11      → P24347     →    0 ligands found...
# SFRP4      → Q6FHJ7     →    0 ligands found...
# NMU        → P48645     →    0 ligands found...
# MSX2       → P35548     →    0 ligands found...
# LY6G6D     → O95868     →    0 ligands found...
# SCD        → O00767     →    0 ligands found...
# TNFRSF11B  → O00300     →    0 ligands found...
# TRIM29     → Q14134     →    0 ligands found...
# PMAIP1     → Q13794     →    0 ligands found...
# COL1A1     → P02452     →    0 ligands found...
# BGN        → P21810     →    0 ligands found...
# UBD        → O15205     →    0 ligands found...
# ENC1       → O14682     →    0 ligands found...
# ETV4       → P43268     →    0 ligands found...
# VSNL1      → P62760     →    0 ligands found...
# AZGP1      → P25311     →    0 ligands found...
# TMEPAI     → Q969W9     →    0 ligands found...
# SLC6A14    → Q9UN76     →    0 ligands found...
# EDNRA      → P25101     →    0 ligands found...
# MMP12      → P39900     →    0 ligands found...
# LCN2       → P80188     →    0 ligands found...
# MFAP2      → P55001     →    0 ligands found...
# MET        → Q9NWH9     →    0 ligands found...
# PDPN       → Q86YL7     →    0 ligands found...
# PHLDA1     → Q8WV24     →    0 ligands found...
# CLDN1      → O95832     →    0 ligands found...
# DACH1      → Q9UI36     →    0 ligands found...
# SLC7A11    → Q9UPY5     →    0 ligands found...
# IMP-3     : Response error. Skipping...
# IMP-3      → Unknown. Skipping...
# EREG       → O14944     →    0 ligands found...
# CSPG2      → P13611     →    0 ligands found...
# BCL2A1     → Q16548     →    0 ligands found...
# BM039     : Response error. Skipping...
# BM039      → Unknown. Skipping...
# ECT2       → Q9H8V3     →    0 ligands found...
# CXCL2      → P19875     →    0 ligands found...
# TGFBI      → Q15582     →    0 ligands found...
# GDF15      → Q99988     →    0 ligands found...
# NEBL       → O76041     →    0 ligands found...
# DUOX2      → Q9NRD8     →    0 ligands found...
# SRPX2      → O60687     →    0 ligands found...
# Loaded 149 genes from ovarian.csv...
# Found 132 unique genes...
# TACSTD2    → P09758     →    0 ligands found...
# KRT7       → P08729     →    0 ligands found...
# CD24       → P25063     →    0 ligands found...
# TACSTD1    → P16422     →    0 ligands found...
# CLDN3      → O15551     →    0 ligands found...
# WFDC2      → Q14508     →    0 ligands found...
# SCNN1A     → P37088     →    0 ligands found...
# CDH1       → Q9UM11     →    0 ligands found...
# UCP2       → P55851     →    0 ligands found...
# CDC2       → P06493     →    0 ligands found...
# PAX8       → Q06710     →    0 ligands found...
# SLPI       → P03973     →    0 ligands found...
# ARHGAP8    → Unknown. Skipping...
# C10orf3    → Q53EZ4     →    0 ligands found...
# KRT8       → P05787     →    0 ligands found...
# ASPM       → Q8IZT6     →    0 ligands found...
# MUC1       → P15941     →    0 ligands found...
# TPD52      → P55327     →    0 ligands found...
# SOX17      → Q9H6I2     →    0 ligands found...
# DSP        → P15924     →    0 ligands found...
# KRT18      → P05783     →    0 ligands found...
# GALNT3     → Q14435     →    0 ligands found...
# TOP2A      → P11388     →    0 ligands found...
# ECT2       → Q9H8V3     →    0 ligands found...
# NEK2       → P51955     →    0 ligands found...
# CELSR1     → Q9NYQ6     →    0 ligands found...
# EZH2       → Q15910     →    0 ligands found...
# PSF1       → Q03518     →    0 ligands found...
# VAMP8      → Q9BV40     →    0 ligands found...
# EVI1       → Q03112     →    0 ligands found...
# ANXA3      → P12429     →    0 ligands found...
# EPS8L1     → Q8TE68     →    0 ligands found...
# RRM2       → P31350     →    0 ligands found...
# TTK        → P33981     →    0 ligands found...
# MAP7       → Q14244     →    0 ligands found...
# HMGA1      → P17096     →    0 ligands found...
# DSG2       → Q14126     →    0 ligands found...
# BUB1       → O43683     →    0 ligands found...
# RBM35A     → Q6NXG1     →    0 ligands found...
# ARL7       → P56559     →    0 ligands found...
# SPINT1     → O43278     →    0 ligands found...
# DSU        → Q8N565     →    0 ligands found...
# KIF11      → P52732     →    0 ligands found...
# PERP       → Q96FX8     →    0 ligands found...
# HCAP-G    : Response error. Skipping...
# HCAP-G     → Unknown. Skipping...
# ERBB3      → P21860     →    0 ligands found...
# MAD2L1     → Q13257     →    0 ligands found...
# TFAP2C     → Q92754     →    0 ligands found...
# CENPA      → P49450     →    0 ligands found...
# KIF20A     → O95235     →    0 ligands found...
# CKS2       → P33552     →    0 ligands found...
# RACGAP1    → Q9H0H5     →    0 ligands found...
# SOX9       → P48436     →    0 ligands found...
# KIAA0101   → Q15004     →    0 ligands found...
# KIF14      → Q15058     →    0 ligands found...
# MTF2       → Q9Y483     →    0 ligands found...
# LY75       → O60449     →    0 ligands found...
# SMC4L1     → Q9NTJ3     →    0 ligands found...
# CXADR      → P78310     →    0 ligands found...
# HMMR       → O75330     →    0 ligands found...
# CD47       → Q08722     →    0 ligands found...
# LAMA5      → O15230     →    0 ligands found...
# TPX2       → Q9ULW0     →    0 ligands found...
# PBK        → Q96KB5     →    0 ligands found...
# ST14       → Q9Y5Y6     →    0 ligands found...
# CD9        → P21926     →    0 ligands found...
# ELF3       → P78545     →    0 ligands found...
# CLDN7      → O95471     →    0 ligands found...
# ROD1       → O95758     →    0 ligands found...
# IDH2       → P48735     →    0 ligands found...
# CD2AP      → Q9Y5K6     →    0 ligands found...
# RPL39L     → Q96EH5     →    0 ligands found...
# DTL        → Q9NZJ0     →    0 ligands found...
# DLG7       → Q15398     →    0 ligands found...
# CENPF      → P49454     →    0 ligands found...
# SLC38A1    → Q9H2H9     →    0 ligands found...
# ATAD2      → Q6PL18     →    0 ligands found...
# KIF15      → Q9NS87     →    0 ligands found...
# VEGF       → P15692     →    0 ligands found...
# MKI67      → P46013     →    0 ligands found...
# CDCA3      → Q99618     →    0 ligands found...
# ZWILCH     → Q9H900     →    0 ligands found...
# CENTD1     → Q8WZ64     →    0 ligands found...
# LACTB2     → Q53H82     →    0 ligands found...
# GRHL2      → Q6ISB3     →    0 ligands found...
# MLF1IP     → Q71F23     →    0 ligands found...
# ST3GAL6    → Q9Y274     →    0 ligands found...
# OSBPL10    → Q9BXB5     →    0 ligands found...
# DNMT3B     → Q9UBC3     →    0 ligands found...
# PAIP1      → Q9H074     →    0 ligands found...
# BUB1B      → O60566     →    0 ligands found...
# ZWINT      → O95229     →    0 ligands found...
# PTPRF      → P10586     →    0 ligands found...
# KIAA0746   → Q68CR1     →    0 ligands found...
# LISCH7    : Response error. Skipping...
# LISCH7     → Unknown. Skipping...
# TOM1L1     → O75674     →    0 ligands found...
# S100A11    → P31949     →    0 ligands found...
# MELK       → Q14680     →    0 ligands found...
# PRC1       → O43663     →    0 ligands found...
# TNFRSF21   → O75509     →    0 ligands found...
# DERA       → Q9Y315     →    0 ligands found...
# MCM4       → P33991     →    0 ligands found...
# LOC146909 : Response error. Skipping...
# LOC146909  → Unknown. Skipping...
# TES        → Q9UGI8     →    0 ligands found...
# MOBK1B     → Q9H8S9     →    0 ligands found...
# ENPP4      → Q9Y6X5     →    0 ligands found...
# CELSR2     → Q9HCU4     →    0 ligands found...
# ATP6V1C1   → P21283     →    0 ligands found...
# CCNB2      → O95067     →    0 ligands found...
# CD58       → P19256     →    0 ligands found...
# NUSAP1     → Q9BXS6     →    0 ligands found...
# SRD5A1     → P18405     →    0 ligands found...
# LSM5       → Q9Y4Y9     →    0 ligands found...
# ZNF217     → O75362     →    0 ligands found...
# TMEM30B    → Q3MIR4     →    0 ligands found...
# PELI1      → Q96FA3     →    0 ligands found...
# FER1L3     → Q9NZM1     →    0 ligands found...
# NRAS       → P01111     →    0 ligands found...
# JUP        → P14923     →    0 ligands found...
# GM632     : Response error. Skipping...
# GM632      → Unknown. Skipping...
# ASK        → Q9UBU7     →    0 ligands found...
# MYO6       → Q9UM54     →    0 ligands found...
# FAM82B     → Q96DB5     →    0 ligands found...
# CRIPT      → Q9P021     →    0 ligands found...
# CDCP1      → Q9H5V8     →    0 ligands found...
# OVOL2      → Q9BRP0     →    0 ligands found...
# TMEM48     → Q9BTX1     →    0 ligands found...
# TNFAIP8    → O95379     →    0 ligands found...
# GPR56      → Q9Y653     →    0 ligands found...
# FLJ21901  : Response error. Skipping...
# FLJ21901   → Unknown. Skipping...
# KIBRA     : Response error. Skipping...
# KIBRA      → Unknown. Skipping...
# CCNB1      → P14635     →    0 ligands found...
# Loaded 575 genes from astrocytoma.csv...
# Found 496 unique genes...
# LTF        → P02788     →    0 ligands found...
# FABP7      → O15540     →    0 ligands found...
# SOX11      → P35716     →    0 ligands found...
# TMSL8      → P0CG34     →    0 ligands found...
# AQP4       → P55087     →    0 ligands found...
# TOP2A      → P11388     →    0 ligands found...
# COL11A1    → P12107     →    0 ligands found...
# CHI3L1     → P36222     →    0 ligands found...
# PDPN       → Q86YL7     →    0 ligands found...
# IL13RA2    → Q14627     →    0 ligands found...
# PTX3       → P26022     →    0 ligands found...
# CDC2       → P06493     →    0 ligands found...
# IL1RAP     → Q9NPH3     →    0 ligands found...
# LOX        → P28300     →    0 ligands found...
# ASCL1      → P50553     →    0 ligands found...
# PBK        → Q96KB5     →    0 ligands found...
# SAA1       → P0DJI8     →    0 ligands found...
# PSPH       → P78330     →    0 ligands found...
# CKS2       → P33552     →    0 ligands found...
# DTL        → Q9NZJ0     →    0 ligands found...
# SOD2       → P04179     →    0 ligands found...
# F2R        → P25116     →    0 ligands found...
# MAD2L1     → Q13257     →    0 ligands found...
# SERPINE1   → P05121     →    0 ligands found...
# TFPI       → P10646     →    0 ligands found...
# LY96       → Q9Y6Y9     →    0 ligands found...
# S100A8     → P05109     →    0 ligands found...
# NUSAP1     → Q9BXS6     →    0 ligands found...
# IMP-3     : Response error. Skipping...
# IMP-3      → Unknown. Skipping...
# RRM2       → P31350     →    0 ligands found...
# ASPM       → Q8IZT6     →    0 ligands found...
# POSTN      → Q15063     →    0 ligands found...
# BCHE       → P06276     →    0 ligands found...
# TNFAIP6    → P98066     →    0 ligands found...
# MS4A4A     → Q96JQ5     →    0 ligands found...
# HS2ST1     → Q7LGA3     →    0 ligands found...
# TCF8       → P37275     →    0 ligands found...
# MLF1IP     → Q71F23     →    0 ligands found...
# PSF1       → Q03518     →    0 ligands found...
# FAM5C      → Q76B58     →    0 ligands found...
# TDO2       → P48775     →    0 ligands found...
# TMEM45A    → Q9NWC5     →    0 ligands found...
# SERPINA3   → P01011     →    0 ligands found...
# LYPD1      → Q8N2G4     →    0 ligands found...
# MSR1       → P21757     →    0 ligands found...
# ANXA1      → P04083     →    0 ligands found...
# EZH2       → Q15910     →    0 ligands found...
# ECT2       → Q9H8V3     →    0 ligands found...
# NNMT       → P40261     →    0 ligands found...
# ASK        → Q9UBU7     →    0 ligands found...
# LSM5       → Q9Y4Y9     →    0 ligands found...
# PBEF1      → P43490     →    0 ligands found...
# KLHL7      → Q8IXQ5     →    0 ligands found...
# HP         → Unknown. Skipping...
# CD163      → Q86VB7     →    0 ligands found...
# IGFBP2     → P18065     →    0 ligands found...
# PLA2G5     → P39877     →    0 ligands found...
# RIT1       → Q92963     →    0 ligands found...
# HAS2       → Q92819     →    0 ligands found...
# SCG3       → Q8WXD2     →    0 ligands found...
# CGI-115    → Q9Y3B9     →    0 ligands found...
# CDKN2A     → P42771     →    0 ligands found...
# C9orf26    → O95760     →    0 ligands found...
# SOX4       → Q06945     →    0 ligands found...
# NEK2       → P51955     →    0 ligands found...
# TTK        → P33981     →    0 ligands found...
# DENND2A    → Q9ULE3     →    0 ligands found...
# CLEC2B     → Q92478     →    0 ligands found...
# DCX        → O43602     →    0 ligands found...
# RAD51AP1   → Q96B01     →    0 ligands found...
# DLL3       → Q9NYJ7     →    0 ligands found...
# EGFR       → P00533     →    0 ligands found...
# ELOVL2     → Q9NXB9     →    0 ligands found...
# ANGPT2     → O15123     →    0 ligands found...
# KIAA0101   → Q15004     →    0 ligands found...
# C8orf4     → Q9NR00     →    0 ligands found...
# CA3        → P07451     →    0 ligands found...
# LRP1B      → Q9NZR2     →    0 ligands found...
# CHRNA9     → Q9UGM1     →    0 ligands found...
# NXT2       → Q9NPJ8     →    0 ligands found...
# ZFP36L2    → P47974     →    0 ligands found...
# KCNE4      → Q8WWG9     →    0 ligands found...
# KIF14      → Q15058     →    0 ligands found...
# DTNA       → Q9Y4J8     →    0 ligands found...
# MMP16      → P51512     →    0 ligands found...
# S100A9     → P06702     →    0 ligands found...
# FLJ10970  : Response error. Skipping...
# FLJ10970   → Unknown. Skipping...
# BBOX1      → O75936     →    0 ligands found...
# MYCN       → P04198     →    0 ligands found...
# DNAJB9     → Q9UBS3     →    0 ligands found...
# HMMR       → O75330     →    0 ligands found...
# CXCL5      → P42830     →    0 ligands found...
# TMPO       → P42166     →    0 ligands found...
# BUB1       → O43683     →    0 ligands found...
# IGFBP3     → P17936     →    0 ligands found...
# RKHD2      → Q5U5Q3     →    0 ligands found...
# DPYD       → Q12882     →    0 ligands found...
# SOX3       → P41225     →    0 ligands found...
# RNASE2     → P10153     →    0 ligands found...
# PPM1D      → O15297     →    0 ligands found...
# PEX12      → O00623     →    0 ligands found...
# CYTL1      → Q9NRR1     →    0 ligands found...
# SHCBP1     → Q8NEM2     →    0 ligands found...
# LRRC17     → Q8N6Y2     →    0 ligands found...
# PLSCR1     → O15162     →    0 ligands found...
# RECQL      → P46063     →    0 ligands found...
# EN1        → Q05925     →    0 ligands found...
# CP         → P00450     →    0 ligands found...
# NOVA1      → P51513     →    0 ligands found...
# EDNRA      → P25101     →    0 ligands found...
# FLJ23560  : Response error. Skipping...
# FLJ23560   → Unknown. Skipping...
# CSRP2      → Q16527     →    0 ligands found...
# TIMP4      → Q99727     →    0 ligands found...
# CLEC5A     → Q9NY25     →    0 ligands found...
# TRA@       → Unknown. Skipping...
# NLGN1      → Q8N2Q7     →    0 ligands found...
# ATAD2      → Q6PL18     →    0 ligands found...
# KIF11      → P52732     →    0 ligands found...
# RHOQ       → Unknown. Skipping...
# MGC39900  : Response error. Skipping...
# MGC39900   → Unknown. Skipping...
# TSFM       → P43897     →    0 ligands found...
# WNT5A      → P41221     →    0 ligands found...
# CD44       → P16070     →    0 ligands found...
# LOC146909 : Response error. Skipping...
# LOC146909  → Unknown. Skipping...
# CSPG2      → P13611     →    0 ligands found...
# KLRC3      → Q07444     →    0 ligands found...
# SLC38A6    → Q8IZM9     →    0 ligands found...
# DLG7       → Q15398     →    0 ligands found...
# SAA1       → Unknown. Skipping...
# SNTG1      → Q9NSN8     →    0 ligands found...
# PHLDA1     → Q8WV24     →    0 ligands found...
# EIF1AY     → O14602     →    0 ligands found...
# GPR65      → Q8IYL9     →    0 ligands found...
# FOXG1B     → P55316     →    0 ligands found...
# GPNMB      → Q14956     →    0 ligands found...
# HRASLS     → Q9HDD0     →    0 ligands found...
# DPYSL3     → Q14195     →    0 ligands found...
# CD58       → P19256     →    0 ligands found...
# IF         → P05156     →    0 ligands found...
# FBXO5      → Q9UKT4     →    0 ligands found...
# TREM1      → Q9NP99     →    0 ligands found...
# HCAP-G    : Response error. Skipping...
# HCAP-G     → Unknown. Skipping...
# ZNF588     → Q9UII5     →    0 ligands found...
# LIPG       → Q9Y5X9     →    0 ligands found...
# SNAPC1     → Q16533     →    0 ligands found...
# CENPA      → P49450     →    0 ligands found...
# ACTL6A     → O96019     →    0 ligands found...
# NR2E1      → Q9Y466     →    0 ligands found...
# PLA2G4A    → P47712     →    0 ligands found...
# IL8        → P10145     →    0 ligands found...
# HLA-DQA1   → P01909     →    0 ligands found...
# VEGF       → P15692     →    0 ligands found...
# NUP160     → Q12769     →    0 ligands found...
# TAF9L      → Q9HBM6     →    0 ligands found...
# PACRG      → Q96M98     →    0 ligands found...
# TMEM5      → Q9Y2B1     →    0 ligands found...
# SLC16A4    → O15374     →    0 ligands found...
# CNIH3      → Q8TBE1     →    0 ligands found...
# FBN2       → P35556     →    0 ligands found...
# PTPRG      → P23470     →    0 ligands found...
# SOCS2      → O14508     →    0 ligands found...
# TNC        → P24821     →    0 ligands found...
# KIAA0527   → O60279     →    0 ligands found...
# VCAM1      → P19320     →    0 ligands found...
# SSA2       → P10155     →    0 ligands found...
# ACN9       → Q9NRP4     →    0 ligands found...
# CALCRL     → Q16602     →    0 ligands found...
# ZWILCH     → Q9H900     →    0 ligands found...
# ZNF228     → Q9Y508     →    0 ligands found...
# KCNQ2      → O43526     →    0 ligands found...
# PDGFC      → Q9NRA1     →    0 ligands found...
# DKK1       → O94907     →    0 ligands found...
# CXCL6      → P80162     →    0 ligands found...
# KNTC2      → O14777     →    0 ligands found...
# TOX        → O94900     →    0 ligands found...
# CHI3L2     → Q15782     →    0 ligands found...
# SRPX2      → O60687     →    0 ligands found...
# GALNT2     → Q10471     →    0 ligands found...
# LIFR       → P42702     →    0 ligands found...
# FLJ13946  : Response error. Skipping...
# FLJ13946   → Unknown. Skipping...
# FPGT       → O14772     →    0 ligands found...
# C9orf116   → Q5BN46     →    0 ligands found...
# ANP32E     → Q9BTT0     →    0 ligands found...
# CLGN       → O14967     →    0 ligands found...
# CDKN2C     → P42773     →    0 ligands found...
# PCDHGC3    → Q9UN70     →    0 ligands found...
# MAPKAPK2   → P49137     →    0 ligands found...
# HSPC138    → Q53FT3     →    0 ligands found...
# GPR17      → Q13304     →    0 ligands found...
# BCAT1      → P54687     →    0 ligands found...
# DPYSL4     → O14531     →    0 ligands found...
# C2orf3     → P16383     →    0 ligands found...
# CHEK1      → O14757     →    0 ligands found...
# FLJ21657  : Response error. Skipping...
# FLJ21657   → Unknown. Skipping...
# YEATS4     → O95619     →    0 ligands found...
# LIN7C      → Q9NUP9     →    0 ligands found...
# WEE1       → P30291     →    0 ligands found...
# FAM70A     → Q5JRV8     →    0 ligands found...
# SOAT1      → P35610     →    0 ligands found...
# EPHA3      → P29320     →    0 ligands found...
# VAMP4      → O75379     →    0 ligands found...
# SPCS3      → P61009     →    0 ligands found...
# TFAM       → Q00059     →    0 ligands found...
# PRKD3      → O94806     →    0 ligands found...
# SPAST      → Q9UBP0     →    0 ligands found...
# LRAP       → Q6P179     →    0 ligands found...
# KIF15      → Q9NS87     →    0 ligands found...
# TMED5      → Q9Y3A6     →    0 ligands found...
# ETNK1      → Q9HBU6     →    0 ligands found...
# SMC4L1     → Q9NTJ3     →    0 ligands found...
# FOXD1      → Q16676     →    0 ligands found...
# GPR19      → Q15760     →    0 ligands found...
# KIAA0555   → Q96AA8     →    0 ligands found...
# MEOX2      → P50222     →    0 ligands found...
# HOXC10     → Q9NYD6     →    0 ligands found...
# C5R1       → P21730     →    0 ligands found...
# PCOLCE2    → Q9UKZ9     →    0 ligands found...
# FJX1       → Q86VR8     →    0 ligands found...
# MTMR1      → Q13613     →    0 ligands found...
# OGFRL1     → Q5TC84     →    0 ligands found...
# ZNF287     → Q9HBT7     →    0 ligands found...
# SIP1       → Q99590     →    0 ligands found...
# STCH       → P48723     →    0 ligands found...
# B3GALT3    → O75752     →    0 ligands found...
# BACH1      → Q9BX63     →    0 ligands found...
# FLJ10178  : Response error. Skipping...
# FLJ10178   → Unknown. Skipping...
# MTHFD2L    → Q9H903     →    0 ligands found...
# CYBRD1     → Q53TN4     →    0 ligands found...
# ZP3        → Unknown. Skipping...
# FCGR3A     → Unknown. Skipping...
# OXTR       → P30559     →    0 ligands found...
# EMP1       → P54849     →    0 ligands found...
# SMARCA5    → O60264     →    0 ligands found...
# CKLF       → Q13887     →    0 ligands found...
# SAMSN1     → Q9NSI8     →    0 ligands found...
# PLOD2      → O00469     →    0 ligands found...
# CMKOR1     → P25106     →    0 ligands found...
# POT1       → Q9NUX5     →    0 ligands found...
# C1RL       → Q9NZP8     →    0 ligands found...
# ADAMTS3    → O15072     →    0 ligands found...
# MYO10      → Q9HD67     →    0 ligands found...
# E2F5       → Q15329     →    0 ligands found...
# SLC4A7     → Q9Y6M7     →    0 ligands found...
# SETMAR     → Q53H47     →    0 ligands found...
# ELK3       → P41970     →    0 ligands found...
# IGF2       → P01344     →    0 ligands found...
# MAFF       → Q9ULX9     →    0 ligands found...
# SNAI2      → O43623     →    0 ligands found...
# MTHFD2     → P13995     →    0 ligands found...
# DDX3Y      → O15523     →    0 ligands found...
# BCAN       → Q96GW7     →    0 ligands found...
# METAP2     → P50579     →    0 ligands found...
# TIMP1      → P01033     →    0 ligands found...
# EIF1AX     → P47813     →    0 ligands found...
# FLJ12442  : Response error. Skipping...
# FLJ12442   → Unknown. Skipping...
# ARTS-1     → Unknown. Skipping...
# FLJ11712  : Response error. Skipping...
# FLJ11712   → Unknown. Skipping...
# FZD3       → Q9NPG1     →    0 ligands found...
# ARC        → O60936     →    0 ligands found...
# COL1A2     → P08123     →    0 ligands found...
# DNALI1     → O14645     →    0 ligands found...
# RINT-1    : Response error. Skipping...
# RINT-1     → Unknown. Skipping...
# NRAS       → P01111     →    0 ligands found...
# IMPACT     → Q9P2X3     →    0 ligands found...
# PRDX4      → Q13162     →    0 ligands found...
# PRRX1      → P54821     →    0 ligands found...
# BMP7       → P18075     →    0 ligands found...
# MAFB       → Q9Y5Q3     →    0 ligands found...
# GPX7       → Q96SL4     →    0 ligands found...
# KCNE1L     → Q9UJ90     →    0 ligands found...
# TMF1       → P82094     →    0 ligands found...
# CDC7       → O00311     →    0 ligands found...
# COL4A1     → P02462     →    0 ligands found...
# RGS1       → Q08116     →    0 ligands found...
# FZD6       → O60353     →    0 ligands found...
# S100A2     → P29034     →    0 ligands found...
# FCGR1A     → Unknown. Skipping...
# ABCA1      → O95477     →    0 ligands found...
# ID4        → P47928     →    0 ligands found...
# SLC2A10    → O95528     →    0 ligands found...
# FAS        → P25445     →    0 ligands found...
# CTH        → Q96IQ7     →    0 ligands found...
# SLC39A8    → Q9C0K1     →    0 ligands found...
# DSU        → Q8N565     →    0 ligands found...
# FCGR1A     → P12314     →    0 ligands found...
# MYBL1      → P10243     →    0 ligands found...
# ZNF167     → Q9P0L1     →    0 ligands found...
# SOX2       → P48431     →    0 ligands found...
# ZNF84      → P51523     →    0 ligands found...
# DTX3       → Q8N9I9     →    0 ligands found...
# FLJ20516  : Response error. Skipping...
# FLJ20516   → Unknown. Skipping...
# FLJ21908  : Response error. Skipping...
# FLJ21908   → Unknown. Skipping...
# SRR        → Q9GZT4     →    0 ligands found...
# NPL        → Q9BXD5     →    0 ligands found...
# SBLF       → Q9Y6Q2     →    0 ligands found...
# FKBP14     → Q9NWM8     →    0 ligands found...
# GNAS       → Q5JWF2     →    0 ligands found...
# BIRC5      → O15392     →    0 ligands found...
# STK17A     → Q9UEE5     →    0 ligands found...
# ZNF22      → P17026     →    0 ligands found...
# MNS1       → Q8NEH6     →    0 ligands found...
# NTRK2      → Q16620     →    0 ligands found...
# SRD5A1     → P18405     →    0 ligands found...
# CHST7      → Q9NS84     →    0 ligands found...
# TPX2       → Q9ULW0     →    0 ligands found...
# PIG8       → O14681     →    0 ligands found...
# BMP2       → P12643     →    0 ligands found...
# CREM       → Q03060     →    0 ligands found...
# ITPR2      → Q14571     →    0 ligands found...
# PANX1      → Q96RD7     →    0 ligands found...
# GPC5       → P78333     →    0 ligands found...
# RDX        → P35241     →    0 ligands found...
# LOC221981 : Response error. Skipping...
# LOC221981  → Unknown. Skipping...
# RABL5      → Q9H7X7     →    0 ligands found...
# NRP1       → O14786     →    0 ligands found...
# SLN        → O00631     →    0 ligands found...
# TNRC9      → O15405     →    0 ligands found...
# PMAIP1     → Q13794     →    0 ligands found...
# SLC30A5    → Q8TAD4     →    0 ligands found...
# ANGPT1     → Q15389     →    0 ligands found...
# ITSN1      → Q15811     →    0 ligands found...
# OSMR       → Q99650     →    0 ligands found...
# PTGS2      → P35354     →    0 ligands found...
# BTN3A3     → O00478     →    0 ligands found...
# APAF1      → O14727     →    0 ligands found...
# GAS1       → P54826     →    0 ligands found...
# C12orf5    → Q9NQ88     →    0 ligands found...
# MMP7       → P09237     →    0 ligands found...
# SULF1      → Q8IWU6     →    0 ligands found...
# HBD        → P02042     →    0 ligands found...
# NEK4       → P51957     →    0 ligands found...
# ADM        → P35318     →    0 ligands found...
# C21orf62   → Q9NYP8     →    0 ligands found...
# SHOX2      → O60902     →    0 ligands found...
# KAL1       → P23352     →    0 ligands found...
# PLEKHF2    → Q9H8W4     →    0 ligands found...
# APBB2      → Q92870     →    0 ligands found...
# ANKRD6     → Q9Y2G4     →    0 ligands found...
# GADD45G    → O95257     →    0 ligands found...
# CDH11      → P55287     →    0 ligands found...
# LOC390940 : Response error. Skipping...
# LOC390940  → Unknown. Skipping...
# SOCS6      → O14544     →    0 ligands found...
# SCN3A      → Q9NY46     →    0 ligands found...
# FLJ21945  : Response error. Skipping...
# FLJ21945   → Unknown. Skipping...
# CTBS       → Q01459     →    0 ligands found...
# SLC14A1    → Q13336     →    0 ligands found...
# C13orf18   → Q9H714     →    0 ligands found...
# NID1       → P14543     →    0 ligands found...
# ABHD2      → P08910     →    0 ligands found...
# RFC2       → P35250     →    0 ligands found...
# EFHC1      → Q5JVL4     →    0 ligands found...
# FCGBP      → Q9Y6R7     →    0 ligands found...
# TSPAN12    → O95859     →    0 ligands found...
# CLN5       → O75503     →    0 ligands found...
# CDK4       → P11802     →    0 ligands found...
# EDNRB      → P24530     →    0 ligands found...
# PCDHGA12   → Unknown. Skipping...
# CCNB1      → P14635     →    0 ligands found...
# FKSG30     → Q9BYX7     →    0 ligands found...
# LHX2       → P50458     →    0 ligands found...
# RBBP8      → Q99708     →    0 ligands found...
# SP100      → P23497     →    0 ligands found...
# SMC2L1     → O95347     →    0 ligands found...
# ZNF200     → P98182     →    0 ligands found...
# ST8SIA1    → Q92185     →    0 ligands found...
# QKI        → Q96PU8     →    0 ligands found...
# ADAM9      → Q13443     →    0 ligands found...
# NES        → P48681     →    0 ligands found...
# CGI-37     → Q9Y221     →    0 ligands found...
# BCL6       → P41182     →    0 ligands found...
# IGSF6      → O95976     →    0 ligands found...
# CSTA       → P01040     →    0 ligands found...
# ELN        → P15502     →    0 ligands found...
# HRH1       → P35367     →    0 ligands found...
# HOXC6      → P09630     →    0 ligands found...
# VSIG4      → Q9Y279     →    0 ligands found...
# TMEM38B    → Q9NVV0     →    0 ligands found...
# DENND1A    → Q8TEH3     →    0 ligands found...
# C1QB       → P02746     →    0 ligands found...
# OLR1       → P78380     →    0 ligands found...
# RIT2       → Q99578     →    0 ligands found...
# C1orf24    → Q9BZQ8     →    0 ligands found...
# SYNC1      → Q9H7C4     →    0 ligands found...
# GGH        → Q92820     →    0 ligands found...
# PTPN13     → Q12923     →    0 ligands found...
# SMARCA1    → P28370     →    0 ligands found...
# C10orf10   → Q9NTK1     →    0 ligands found...
# PRC1       → O43663     →    0 ligands found...
# NEDD9      → Q14511     →    0 ligands found...
# FLJ10719  : Response error. Skipping...
# FLJ10719   → Unknown. Skipping...
# FLJ10996  : Response error. Skipping...
# FLJ10996   → Unknown. Skipping...
# SAR1B      → Q9Y6B6     →    0 ligands found...
# INSM1      → Q01101     →    0 ligands found...
# CSPG4      → Q6UVK1     →    0 ligands found...
# MSX1       → P28360     →    0 ligands found...
# CTPS2      → Q9NRF8     →    0 ligands found...
# GSTT2      → P0CG29     →    0 ligands found...
# YAF2       → Q8IY57     →    0 ligands found...
# CD99       → P14209     →    0 ligands found...
# CRSP2      → O60244     →    0 ligands found...
# ARHGAP6    → O43182     →    0 ligands found...
# RAD51      → Q06609     →    0 ligands found...
# RPL23AP7  : Response error. Skipping...
# RPL23AP7   → Unknown. Skipping...
# TSPAN6     → O43657     →    0 ligands found...
# KIF4A      → O95239     →    0 ligands found...
# GEM        → P55040     →    0 ligands found...
# UBE2S      → Q16763     →    0 ligands found...
# IFI16      → Q16666     →    0 ligands found...
# FLJ20035  : Response error. Skipping...
# FLJ20035   → Unknown. Skipping...
# OLIG2      → Q13516     →    0 ligands found...
# TWIST1     → Q15672     →    0 ligands found...
# MERTK      → Q12866     →    0 ligands found...
# HIG2       → Q9Y5L2     →    0 ligands found...
# KLHL20     → Q9Y2M5     →    0 ligands found...
# RRAS2      → P62070     →    0 ligands found...
# APOC2      → P02655     →    0 ligands found...
# C8orf1     → Q9Y236     →    0 ligands found...
# WWTR1      → Q9GZV5     →    0 ligands found...
# PDE4DIP    → Q5VU43     →    0 ligands found...
# NDP        → Q00604     →    0 ligands found...
# SEC61G     → P60059     →    0 ligands found...
# RPL18A     → Unknown. Skipping...
# NFIL3      → Q16649     →    0 ligands found...
# FLJ13611  : Response error. Skipping...
# FLJ13611   → Unknown. Skipping...
# SALL1      → Q9NSC2     →    0 ligands found...
# GBE1       → Q04446     →    0 ligands found...
# GLT28D1    → Q9NP73     →    0 ligands found...
# CSPG5      → O95196     →    0 ligands found...
# FLJ22222  : Response error. Skipping...
# FLJ22222   → Unknown. Skipping...
# TREM2      → Q9NZC2     →    0 ligands found...
# TYMS       → P04818     →    0 ligands found...
# EFHC2      → Q5JST6     →    0 ligands found...
# EMP3       → P54852     →    0 ligands found...
# C1QR1      → Q9NPY3     →    0 ligands found...
# CITED1     → Q99966     →    0 ligands found...
# HBXAP      → Q96T23     →    0 ligands found...
# NMU        → P48645     →    0 ligands found...
# BNIP2      → Q12982     →    0 ligands found...
# SEC10L1    → O00471     →    0 ligands found...
# C1orf109   → Q9NX04     →    0 ligands found...
# SEC22L2    → Q96IW7     →    0 ligands found...
# ETV1       → P50549     →    0 ligands found...
# C14orf135  → Q63HM2     →    0 ligands found...
# C9orf76    → Q9H9A7     →    0 ligands found...
# EFEMP1     → Q12805     →    0 ligands found...
# PTPN12     → Q05209     →    0 ligands found...
# CUL4B      → Q13620     →    0 ligands found...
# MELK       → Q14680     →    0 ligands found...
# EMX2       → Q04743     →    0 ligands found...
# GNAI3      → P08754     →    0 ligands found...
# TRD@      : Response error. Skipping...
# TRD@       → Unknown. Skipping...
# PROS1      → P07225     →    0 ligands found...
# CXCR4      → P61073     →    0 ligands found...
# RAP2C      → Q9Y3L5     →    0 ligands found...
# RRAGD      → Q9NQL2     →    0 ligands found...
# C20orf42   → Q9BQL6     →    0 ligands found...
# TLR3       → O15455     →    0 ligands found...
# LIMS1      → P48059     →    0 ligands found...
# DKFZP586D0919: Response error. Skipping...
# DKFZP586D0919 → Unknown. Skipping...
# ST3GAL6    → Q9Y274     →    0 ligands found...
# YES1       → P07947     →    0 ligands found...
# CCL4       → P13236     →    0 ligands found...
# ODC1       → P11926     →    0 ligands found...
# SHMT2      → P34897     →    0 ligands found...
# BMPR1A     → P36894     →    0 ligands found...
# ZNF217     → O75362     →    0 ligands found...
# CCND2      → P30279     →    0 ligands found...
# KIAA0992   → Q8WX93     →    0 ligands found...
# LRP8       → Q14114     →    0 ligands found...
# CACNG4     → Q9UBN1     →    0 ligands found...
# C21orf66   → Q9Y5B6     →    0 ligands found...
# STK6       → O14965     →    0 ligands found...
# NMI        → Q13287     →    0 ligands found...
# ID3        → Q02535     →    0 ligands found...
# C19orf6    → Q4ZIN3     →    0 ligands found...
# DIRAS3     → O95661     →    0 ligands found...
# DHX40      → Q8IX18     →    0 ligands found...
# FARS2      → O95363     →    0 ligands found...
# MCL1       → Q07820     →    0 ligands found...
# ICAM1      → P05362     →    0 ligands found...
# IGFBP5     → P24593     →    0 ligands found...
# KIF20A     → O95235     →    0 ligands found...
# STK38L     → Q9Y2H1     →    0 ligands found...
# PAICS      → P22234     →    0 ligands found...
# MOSPD1     → Q9UJG1     →    0 ligands found...
# CNIH4      → Q9P003     →    0 ligands found...
# KNTC1      → P50748     →    0 ligands found...
# S100A11    → P31949     →    0 ligands found...
# FLJ20647  : Response error. Skipping...
# FLJ20647   → Unknown. Skipping...
# FGF2       → P09038     →    0 ligands found...
# CGI-121    → Q9Y3C4     →    0 ligands found...
# KCNIP1     → Q9NZI2     →    0 ligands found...
# UBE2C      → O00762     →    0 ligands found...
# GMNN       → O75496     →    0 ligands found...
# TPST1      → O60507     →    0 ligands found...
# Loaded 637 genes from liver.csv...
# Found 553 unique genes...
# KRT19      → P08727     →    0 ligands found...
# COL11A1    → P12107     →    0 ligands found...
# OLFM4      → Q6UX06     →    0 ligands found...
# NOX1       → Q9Y5S8     →    0 ligands found...
# CCL18      → P55774     →    0 ligands found...
# COMP       → P49747     →    0 ligands found...
# CEACAM6    → P40199     →    0 ligands found...
# FAP        → Q12884     →    0 ligands found...
# MMP12      → P39900     →    0 ligands found...
# TACSTD1    → P16422     →    0 ligands found...
# SULF1      → Q8IWU6     →    0 ligands found...
# COL10A1    → Q03692     →    0 ligands found...
# CDH3       → P55291     →    0 ligands found...
# PLCB4      → Q15147     →    0 ligands found...
# CD24       → P25063     →    0 ligands found...
# AGR2       → O95994     →    0 ligands found...
# C20orf42   → Q9BQL6     →    0 ligands found...
# CSPG2      → P13611     →    0 ligands found...
# POSTN      → Q15063     →    0 ligands found...
# TACSTD2    → P09758     →    0 ligands found...
# COL1A2     → P08123     →    0 ligands found...
# CDC2       → P06493     →    0 ligands found...
# MSLN       → Q13421     →    0 ligands found...
# MUC1       → P15941     →    0 ligands found...
# GALNT3     → Q14435     →    0 ligands found...
# CDH11      → P55287     →    0 ligands found...
# CDH17      → Q12864     →    0 ligands found...
# CEACAM5    → P06731     →    0 ligands found...
# S100A6     → P06703     →    0 ligands found...
# GPRC5A     → Q8NFJ5     →    0 ligands found...
# MAGEA6     → P43360     →    0 ligands found...
# IGLC2      → P0DOY2     →    0 ligands found...
# HOXA9      → P31269     →    0 ligands found...
# C13orf18   → Q9H714     →    0 ligands found...
# RUNX1      → Q01196     →    0 ligands found...
# KRT20      → P35900     →    0 ligands found...
# RAB25      → P57735     →    0 ligands found...
# SEMA3C     → Q99985     →    0 ligands found...
# PMAIP1     → Q13794     →    0 ligands found...
# LOX        → P28300     →    0 ligands found...
# SOX4       → Q06945     →    0 ligands found...
# SPON1      → Q9HCB6     →    0 ligands found...
# WT1        → P19544     →    0 ligands found...
# KLK10      → O43240     →    0 ligands found...
# EREG       → O14944     →    0 ligands found...
# COL15A1    → P39059     →    0 ligands found...
# FXYD3      → Q14802     →    0 ligands found...
# CLIC3      → O95833     →    0 ligands found...
# AREG       → P15514     →    0 ligands found...
# KLF5       → Q13887     →    0 ligands found...
# INHBA      → P08476     →    0 ligands found...
# TOP2A      → P11388     →    0 ligands found...
# MFAP5      → Q13361     →    0 ligands found...
# HOP        → Q9BPY8     →    0 ligands found...
# KRT7       → P08729     →    0 ligands found...
# KIAA1199   → Q8WUJ3     →    0 ligands found...
# TRIM29     → Q14134     →    0 ligands found...
# ANXA3      → P12429     →    0 ligands found...
# KRT17      → Q04695     →    0 ligands found...
# RGS1       → Q08116     →    0 ligands found...
# TPM2       → P07951     →    0 ligands found...
# GAS1       → P54826     →    0 ligands found...
# COL8A2     → P25067     →    0 ligands found...
# BHLHB3     → Q9C0J9     →    0 ligands found...
# SPP1       → P10451     →    0 ligands found...
# S100P      → P25815     →    0 ligands found...
# GPCR5A     → Q8NFJ5     →    0 ligands found...
# LPL        → P06858     →    0 ligands found...
# FABP5      → Q01469     →    0 ligands found...
# NQO1       → P15559     →    0 ligands found...
# LRRC1      → Q9BTT6     →    0 ligands found...
# C1orf116   → Q9BW04     →    0 ligands found...
# SFRP4      → Q6FHJ7     →    0 ligands found...
# MAGEA3     → P43357     →    0 ligands found...
# KCNQ1      → P51787     →    0 ligands found...
# ECT2       → Q9H8V3     →    0 ligands found...
# TMEPAI     → Q969W9     →    0 ligands found...
# HDGFRP3    → Q9Y3E1     →    0 ligands found...
# TFF3       → Q07654     →    0 ligands found...
# SPINT1     → O43278     →    0 ligands found...
# PAFAH1B3   → Q15102     →    0 ligands found...
# LGR5       → O75473     →    0 ligands found...
# VAV3       → Q9UKW4     →    0 ligands found...
# RBM35A     → Q6NXG1     →    0 ligands found...
# ANXA1      → P04083     →    0 ligands found...
# ZNF83      → P51522     →    0 ligands found...
# PDPN       → Q86YL7     →    0 ligands found...
# TFF1       → P04155     →    0 ligands found...
# MGP        → P08493     →    0 ligands found...
# GPSM2      → P81274     →    0 ligands found...
# KRT23      → Q9C075     →    0 ligands found...
# CDS1       → O96017     →    0 ligands found...
# LUM        → P51884     →    0 ligands found...
# FZD2       → Q14332     →    0 ligands found...
# KNTC2      → O14777     →    0 ligands found...
# CRIP1      → P50238     →    0 ligands found...
# HIST1H2BG  → P62807     →    0 ligands found...
# COL1A1     → P02452     →    0 ligands found...
# C1orf106   → Q3KP66     →    0 ligands found...
# BM039     : Response error. Skipping...
# BM039      → Unknown. Skipping...
# CRABP2     → P29373     →    0 ligands found...
# CYBRD1     → Q53TN4     →    0 ligands found...
# SLC2A5     → P22732     →    0 ligands found...
# ST14       → Q9Y5Y6     →    0 ligands found...
# MFAP2      → P55001     →    0 ligands found...
# MMP9       → P14780     →    0 ligands found...
# ASNS       → P08243     →    0 ligands found...
# NEK2       → P51955     →    0 ligands found...
# GJA1       → P17302     →    0 ligands found...
# ARHGAP8    → Unknown. Skipping...
# CENPA      → P49450     →    0 ligands found...
# NEBL       → O76041     →    0 ligands found...
# RIS1       → Q8WZ71     →    0 ligands found...
# TWIST1     → Q15672     →    0 ligands found...
# ADAM12     → O43184     →    0 ligands found...
# TREM2      → Q9NZC2     →    0 ligands found...
# TDGF1      → P13385     →    0 ligands found...
# C10orf3    → Q53EZ4     →    0 ligands found...
# EFEMP1     → Q12805     →    0 ligands found...
# CLIC5      → Q9NZA1     →    0 ligands found...
# CEL        → P19835     →    0 ligands found...
# IGLV3-25   → P01717     →    0 ligands found...
# HNT       : Response error. Skipping...
# HNT        → Unknown. Skipping...
# DUSP4      → Q13115     →    0 ligands found...
# SERPINH1   → P50454     →    0 ligands found...
# S100A11    → P31949     →    0 ligands found...
# TMPRSS4    → Q9NRS4     →    0 ligands found...
# STC2       → O76061     →    0 ligands found...
# RPL39L     → Q96EH5     →    0 ligands found...
# TSPAN8     → P19075     →    0 ligands found...
# LY75       → O60449     →    0 ligands found...
# EMP1       → P54849     →    0 ligands found...
# WDR46      → O15213     →    0 ligands found...
# GREM1      → O60565     →    0 ligands found...
# GALNT12    → Q8IXK2     →    0 ligands found...
# GALNT7     → Q86SF2     →    0 ligands found...
# CDCP1      → Q9H5V8     →    0 ligands found...
# EHF        → Q9NZC4     →    0 ligands found...
# EDNRA      → P25101     →    0 ligands found...
# MTHFD2     → P13995     →    0 ligands found...
# MUC13      → Q9H3R2     →    0 ligands found...
# PDZK1IP1   → Q13113     →    0 ligands found...
# MAGEA2     → Unknown. Skipping...
# PSF1       → Q03518     →    0 ligands found...
# NPTX2      → P47972     →    0 ligands found...
# IGF1R      → P08069     →    0 ligands found...
# TUBA3      → Q71U36     →    0 ligands found...
# PTPRN2     → Q92932     →    0 ligands found...
# LOXL1      → Q08397     →    0 ligands found...
# QPCT       → Q16769     →    0 ligands found...
# PKM2       → P14618     →    0 ligands found...
# NUP93      → Q8N1F7     →    0 ligands found...
# AEBP1      → Q8IUX7     →    0 ligands found...
# SYK        → P43405     →    0 ligands found...
# LGALS3     → Unknown. Skipping...
# LEF1       → Q9UJU2     →    0 ligands found...
# BCL2A1     → Q16548     →    0 ligands found...
# CYP1B1     → Q16678     →    0 ligands found...
# PYGB       → P11216     →    0 ligands found...
# ITGBL1     → O95965     →    0 ligands found...
# ASPM       → Q8IZT6     →    0 ligands found...
# PHLDA2     → Q53GA4     →    0 ligands found...
# ANTXR1     → Q9H6X2     →    0 ligands found...
# POF1B      → Q8WVV4     →    0 ligands found...
# RACGAP1    → Q9H0H5     →    0 ligands found...
# FLJ12442  : Response error. Skipping...
# FLJ12442   → Unknown. Skipping...
# F3         → P13726     →    0 ligands found...
# MYB        → P10242     →    0 ligands found...
# TTK        → P33981     →    0 ligands found...
# INPP4B     → O15327     →    0 ligands found...
# SLC1A3     → P43003     →    0 ligands found...
# PITX1      → P78337     →    0 ligands found...
# TSPAN1     → O60635     →    0 ligands found...
# BARD1      → Q99728     →    0 ligands found...
# FER1L3     → Q9NZM1     →    0 ligands found...
# ALOX5      → P09917     →    0 ligands found...
# HCAP-G    : Response error. Skipping...
# HCAP-G     → Unknown. Skipping...
# SLAMF8     → Q9P0V8     →    0 ligands found...
# SOX9       → P48436     →    0 ligands found...
# SLC6A8     → P48029     →    0 ligands found...
# ADAMDEC1   → O15204     →    0 ligands found...
# STK39      → Q9UEW8     →    0 ligands found...
# GULP1      → Q9UBP9     →    0 ligands found...
# EPHB2      → P29323     →    0 ligands found...
# MCART1     → Q9H1U9     →    0 ligands found...
# ENO2       → P09104     →    0 ligands found...
# PAM        → O75592     →    0 ligands found...
# KIF23      → Q02241     →    0 ligands found...
# TRAF5      → O00463     →    0 ligands found...
# MLF1       → P58340     →    0 ligands found...
# SPINT2     → O43291     →    0 ligands found...
# SFN        → Q9Y3B8     →    0 ligands found...
# PFKP       → Q01813     →    0 ligands found...
# FBN1       → P35555     →    0 ligands found...
# CXCR4      → P61073     →    0 ligands found...
# SC65       → Q92791     →    0 ligands found...
# CRSP8      → Q6P2C8     →    0 ligands found...
# GLIPR1     → P48060     →    0 ligands found...
# RBM34      → P42696     →    0 ligands found...
# CXCL11     → O14625     →    0 ligands found...
# NOX4       → Q9NPH5     →    0 ligands found...
# NOL3       → O60936     →    0 ligands found...
# CPE        → P16870     →    0 ligands found...
# LGALS1     → P09382     →    0 ligands found...
# CAPG       → Q9BPX3     →    0 ligands found...
# TNFAIP6    → P98066     →    0 ligands found...
# HEPH       → Q9BQS7     →    0 ligands found...
# MNAT1      → P51948     →    0 ligands found...
# BIRC5      → O15392     →    0 ligands found...
# PPP1R3D    → O95685     →    0 ligands found...
# TFAP2A     → P05549     →    0 ligands found...
# PLXNA1     → Q9UIW2     →    0 ligands found...
# COL16A1    → Q07092     →    0 ligands found...
# ISG20      → Q96AZ6     →    0 ligands found...
# EPS8L1     → Q8TE68     →    0 ligands found...
# FAIM       → Q9NVQ4     →    0 ligands found...
# SMYD3      → Q9H7B4     →    0 ligands found...
# MAGEA1     → P43355     →    0 ligands found...
# TWSG1      → Q9GZX9     →    0 ligands found...
# ROBO1      → Q9Y6N7     →    0 ligands found...
# DOCK9      → Q9BZ29     →    0 ligands found...
# MAD2L1     → Q13257     →    0 ligands found...
# COL5A2     → P05997     →    0 ligands found...
# EPHA4      → P54764     →    0 ligands found...
# C20orf19   → Q2M2Z5     →    0 ligands found...
# HOMER1     → Q86YM7     →    0 ligands found...
# NFE2L3     → Q9Y4A8     →    0 ligands found...
# LRRC14     → Q15048     →    0 ligands found...
# THBS2      → P35442     →    0 ligands found...
# VRK1       → Q99986     →    0 ligands found...
# IQGAP1     → P46940     →    0 ligands found...
# PTK6       → Q13882     →    0 ligands found...
# PRC1       → O43663     →    0 ligands found...
# CTBP2      → P56545     →    0 ligands found...
# TACC3      → Q9Y6A5     →    0 ligands found...
# DAF        → P08174     →    0 ligands found...
# RGC32      → Q9H4X1     →    0 ligands found...
# RAB31      → Q13636     →    0 ligands found...
# ZNF532     → Q9HCE3     →    0 ligands found...
# HMMR       → O75330     →    0 ligands found...
# Pfs2      : Response error. Skipping...
# Pfs2       → Unknown. Skipping...
# NUDT1      → P36639     →    0 ligands found...
# NETO2      → Q8NC67     →    0 ligands found...
# PDZRN3     → Q9UPQ7     →    0 ligands found...
# PLP2       → Q04941     →    0 ligands found...
# COL5A1     → P20908     →    0 ligands found...
# MXRA5      → Q9NR99     →    0 ligands found...
# TRPS1      → Q9UHF7     →    0 ligands found...
# CLDN4      → O14493     →    0 ligands found...
# GALNACT-2 : Response error. Skipping...
# GALNACT-2  → Unknown. Skipping...
# PCSK5      → Q92824     →    0 ligands found...
# LAMC2      → Q13753     →    0 ligands found...
# CD200      → P41217     →    0 ligands found...
# ZWILCH     → Q9H900     →    0 ligands found...
# CELSR1     → Q9NYQ6     →    0 ligands found...
# LAMA3      → Q16787     →    0 ligands found...
# KIAA0690   → Q5JTH9     →    0 ligands found...
# TPBG       → Q13641     →    0 ligands found...
# LDHB       → P07195     →    0 ligands found...
# HLA-DQB1   → P01920     →    0 ligands found...
# ATP9A      → O75110     →    0 ligands found...
# HK2        → P52789     →    0 ligands found...
# DNAJC6     → O75061     →    0 ligands found...
# ZNF588     → Q9UII5     →    0 ligands found...
# CBR3       → O75828     →    0 ligands found...
# SCNN1A     → P37088     →    0 ligands found...
# GPR56      → Q9Y653     →    0 ligands found...
# CCNE2      → O96020     →    0 ligands found...
# KIF20A     → O95235     →    0 ligands found...
# STK6       → O14965     →    0 ligands found...
# SLC39A6    → Q13433     →    0 ligands found...
# HTR2B      → P41595     →    0 ligands found...
# BICD2      → Q8TD16     →    0 ligands found...
# ...
# PDZK3      → O15018     →    0 ligands found...
# CACNB3     → P54284     →    0 ligands found...
# PRKDC      → P78527     →    0 ligands found...
# STMN2      → Q93045     →    0 ligands found...
# KLK11      → Q9UBX7     →    0 ligands found...
# TAP1       → Q03518     →    0 ligands found...
# ESRRBL1    → Q9NWB7     →    0 ligands found...
# GPATC1     → Q9BRR8     →    0 ligands found...
# H2AFZ      → P0C0S5     →    0 ligands found...
# GPC4       → O75487     →    0 ligands found...
# FBXL2      → Q9UKC9     →    0 ligands found...
# SPAG4      → Q9NPE6     →    0 ligands found...
# ARHGEF10   → O15013     →    0 ligands found...
# MPHOSPH1   → Q96Q89     →    0 ligands found...
# BCAT1      → P54687     →    0 ligands found...
# KNTC1      → P50748     →    0 ligands found...
# MEP1A      → Q16819     →    0 ligands found...
# KIF4A      → O95239     →    0 ligands found...
# SRI        → P30626     →    0 ligands found...
# PMP22      → Q9NR77     →    0 ligands found...
# TPD52      → P55327     →    0 ligands found...
# CENPF      → P49454     →    0 ligands found...
# KCNE4      → Q8WWG9     →    0 ligands found...
# PTGER4     → P35408     →    0 ligands found...
# RBMS2      → Q15434     →    0 ligands found...
# CBX3       → Q13185     →    0 ligands found...
# ETV1       → P50549     →    0 ligands found...
# CLDN3      → O15551     →    0 ligands found...
# PTPN13     → Q12923     →    0 ligands found...
# ABCF2      → Q9UG63     →    0 ligands found...
# ELF4       → Q99607     →    0 ligands found...
# UTP14A     → Q9BVJ6     →    0 ligands found...
# LOC339229 : Response error. Skipping...
# LOC339229  → Unknown. Skipping...
# CACYBP     → Q9HB71     →    0 ligands found...
# RCN2       → Q14257     →    0 ligands found...
# CAMSAP1L1  → Q08AD1     →    0 ligands found...
# POLH       → Q9Y253     →    0 ligands found...
# SFRS10     → P62995     →    0 ligands found...
# AER61      → Q5NDL2     →    0 ligands found...
# PAK1IP1    → Q9NWT1     →    0 ligands found...
# MMP14      → P50281     →    0 ligands found...
# OSBPL3     → Q9H4L5     →    0 ligands found...
# HOXB6      → P17509     →    0 ligands found...
# HS3ST1     → O14792     →    0 ligands found...
# CUGBP2     → O95319     →    0 ligands found...
# KIAA0746   → Q68CR1     →    0 ligands found...
# ADAM9      → Q13443     →    0 ligands found...
# FUT8       → Q9BYC5     →    0 ligands found...
# ITPR1      → Q14643     →    0 ligands found...
# IGJ        → P01591     →    0 ligands found...
# EBI2       → P32249     →    0 ligands found...
# DACH1      → Q9UI36     →    0 ligands found...
# RECQL      → P46063     →    0 ligands found...
# SPTLC2     → O15270     →    0 ligands found...
# SMARCAL1   → Q9NZC9     →    0 ligands found...
# SAMD9      → Q5K651     →    0 ligands found...
# CTGF       → P29279     →    0 ligands found...
# ANXA11     → P50995     →    0 ligands found...
# ARPC4      → P59998     →    0 ligands found...
# NOTCH3     → Q9UM47     →    0 ligands found...
# TES        → Q9UGI8     →    0 ligands found...
# RDBP       → P18615     →    0 ligands found...
# SCAP2      → O75563     →    0 ligands found...
# CDV1       → Q8WYA0     →    0 ligands found...
# RAB23      → Q9ULC3     →    0 ligands found...
# CSRP2      → Q16527     →    0 ligands found...
# CD58       → P19256     →    0 ligands found...
# GPR172A    → Q9HAB3     →    0 ligands found...
# LAPTM4B    → Q86VI4     →    0 ligands found...
# ALDOA      → P04075     →    0 ligands found...
# CCL8       → P80075     →    0 ligands found...
# GEMIN4     → P57678     →    0 ligands found...
# BACE2      → Q9Y5Z0     →    0 ligands found...
# BTN3A2     → P78410     →    0 ligands found...
# TM4SF1     → P30408     →    0 ligands found...
# PAQR3      → Q6TCH7     →    0 ligands found...
# ITPKB      → P27987     →    0 ligands found...
# MRE11A     → P49959     →    0 ligands found...
# CASP1      → P29466     →    0 ligands found...
# STIP1      → P31948     →    0 ligands found...
# S100A10    → P60903     →    0 ligands found...
# AP1G2      → O75843     →    0 ligands found...
# TAX1BP3    → O14907     →    0 ligands found...
# RFC4       → P35249     →    0 ligands found...
# FLJ12443  : Response error. Skipping...
# FLJ12443   → Unknown. Skipping...
# PFDN4      → Q9NQP4     →    0 ligands found...
# RIN2       → Q8WYP3     →    0 ligands found...
# KIF14      → Q15058     →    0 ligands found...
# C12orf5    → Q9NQ88     →    0 ligands found...
# ATP13A2    → Q9NQ11     →    0 ligands found...
# MICAL1     → Q8TDZ2     →    0 ligands found...
# C1orf139   → Q5T9L3     →    0 ligands found...
# GATA3      → P23771     →    0 ligands found...
# MAPK13     → O15264     →    0 ligands found...
# GOLPH3L    → Q9H4A5     →    0 ligands found...
# DLEU2      → Unknown. Skipping...
# MALL       → Q13021     →    0 ligands found...
# HLA-DQA1   → Unknown. Skipping...
# HOXB7      → P09629     →    0 ligands found...
# ATP1B3     → P54709     →    0 ligands found...
# STARD7     → Q9NQZ5     →    0 ligands found...
# KCTD7      → Q96MP8     →    0 ligands found...
# Loaded 35 genes from thyroid.csv...
# Found 29 unique genes...
# SLC34A2    → O95436     →    0 ligands found...
# CITED1     → Q99966     →    0 ligands found...
# SFTPB      → P07988     →    0 ligands found...
# SERPINA1   → P01009     →    0 ligands found...
# DPP4       → P27487     →    0 ligands found...
# FN1        → P02751     →    0 ligands found...
# PSD3       → Q9NYI0     →    0 ligands found...
# NRCAM      → Q92823     →    0 ligands found...
# HMGA2      → P52926     →    0 ligands found...
# COL13A1    → Q5TAT6     →    0 ligands found...
# QPCT       → Q16769     →    0 ligands found...
# C6orf62    → Q9GZU0     →    0 ligands found...
# ENTPD1     → P49961     →    0 ligands found...
# PLAG1      → Q6DJT9     →    0 ligands found...
# IF         → P05156     →    0 ligands found...
# PLXNC1     → O60486     →    0 ligands found...
# COL1A2     → P08123     →    0 ligands found...
# LAMB3      → Q13751     →    0 ligands found...
# ALOX5      → P09917     →    0 ligands found...
# GALNT2     → Q10471     →    0 ligands found...
# KCNJ2      → P63252     →    0 ligands found...
# AMIGO2     → Q86SJ2     →    0 ligands found...
# NFE2L3     → Q9Y4A8     →    0 ligands found...
# ETV1       → P50549     →    0 ligands found...
# GALNT7     → Q86SF2     →    0 ligands found...
# C14orf78   → Q8IVF2     →    0 ligands found...
# CXorf6     → Q13495     →    0 ligands found...
# DTX4       → Q9Y2E6     →    0 ligands found...
# DNAJC7     → Q99615     →    0 ligands found...
# Loaded 90 genes from breast.csv...
# Found 74 unique genes...
# COL11A1    → P12107     →    0 ligands found...
# COL10A1    → Q03692     →    0 ligands found...
# RRM2       → P31350     →    0 ligands found...
# MELK       → Q14680     →    0 ligands found...
# LRRC15     → Q8TF66     →    0 ligands found...
# CDC2       → P06493     →    0 ligands found...
# CENPF      → P49454     →    0 ligands found...
# STK6       → O14965     →    0 ligands found...
# ASPM       → Q8IZT6     →    0 ligands found...
# TPX2       → Q9ULW0     →    0 ligands found...
# KIAA0101   → Q15004     →    0 ligands found...
# RSAD2      → Q8WXG1     →    0 ligands found...
# FN1        → P02751     →    0 ligands found...
# CCNB2      → O95067     →    0 ligands found...
# CENPA      → P49450     →    0 ligands found...
# G1P2       → P05161     →    0 ligands found...
# CDC20      → Q12834     →    0 ligands found...
# LAMP3      → Q9UQV4     →    0 ligands found...
# KIF4A      → O95239     →    0 ligands found...
# NUSAP1     → Q9BXS6     →    0 ligands found...
# KIF20A     → O95235     →    0 ligands found...
# NEK2       → P51955     →    0 ligands found...
# DTL        → Q9NZJ0     →    0 ligands found...
# COL5A1     → P20908     →    0 ligands found...
# MKI67      → P46013     →    0 ligands found...
# C10orf3    → Q53EZ4     →    0 ligands found...
# CCNE2      → O96020     →    0 ligands found...
# CCNB1      → P14635     →    0 ligands found...
# TTK        → P33981     →    0 ligands found...
# SULF1      → Q8IWU6     →    0 ligands found...
# CDKN3      → Q00526     →    0 ligands found...
# CKS2       → P33552     →    0 ligands found...
# FLJ21736  : Response error. Skipping...
# FLJ21736   → Unknown. Skipping...
# MLF1IP     → Q71F23     →    0 ligands found...
# LOC152719 : Response error. Skipping...
# LOC152719  → Unknown. Skipping...
# DLG7       → Q15398     →    0 ligands found...
# KIF2C      → Q99661     →    0 ligands found...
# CENPE      → Q02224     →    0 ligands found...
# MAD2L1     → Q13257     →    0 ligands found...
# BUB1       → O43683     →    0 ligands found...
# SPP1       → P10451     →    0 ligands found...
# PRC1       → O43663     →    0 ligands found...
# ESPL1      → Q14674     →    0 ligands found...
# RACGAP1    → Q9H0H5     →    0 ligands found...
# AIM2       → O14862     →    0 ligands found...
# KIF11      → P52732     →    0 ligands found...
# FLJ35348  : Response error. Skipping...
# FLJ35348   → Unknown. Skipping...
# BUB1B      → O60566     →    0 ligands found...
# STAT1      → P42224     →    0 ligands found...
# BLM        → P54132     →    0 ligands found...
# SELL       → P14151     →    0 ligands found...
# KIF14      → Q15058     →    0 ligands found...
# RGS1       → Q08116     →    0 ligands found...
# PSF1       → Q03518     →    0 ligands found...
# PTTG1      → O95997     →    0 ligands found...
# NID2       → Q14112     →    0 ligands found...
# HMMR       → O75330     →    0 ligands found...
# COL1A2     → P08123     →    0 ligands found...
# CSPG2      → P13611     →    0 ligands found...
# ATP8A2     → Q9NTI2     →    0 ligands found...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-185c42e7779c> in <module>()
#      18             gene = gene.split("///")[0]
#      19
# ---> 20         gene_table = get_uniprot(gene)
#      21         if gene_table is None:
#      22             print(f"{gene:10} → Unknown. Skipping...")
#
# <ipython-input-5-47c6cf962415> in get_uniprot(gene)
#       7     request = urllib.request.Request(url)
#       8     try:
# ----> 9         response = urllib.request.urlopen(request)
#      10     except urllib.error.HTTPError as e:
#      11         # print(f"{gene:10}: HTTP error. Skipping...")
#
# ~/data/applications/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/data/applications/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/data/applications/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/data/applications/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/data/applications/anaconda3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~/data/applications/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# ~/data/applications/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/data/applications/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# ~/data/applications/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# ~/data/applications/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~/data/applications/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~/data/applications/anaconda3/lib/python3.6/http/client.py in connect(self)
#    1398
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#    1402                 try:
#
# ~/data/applications/anaconda3/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# ~/data/applications/anaconda3/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     812                         # non-blocking
#     813                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 814                     self.do_handshake()
#     815
#     816             except (OSError, ValueError):
#
# ~/data/applications/anaconda3/lib/python3.6/ssl.py in do_handshake(self, block)
#    1066             if timeout == 0.0 and block:
#    1067                 self.settimeout(None)
# -> 1068             self._sslobj.do_handshake()
#    1069         finally:
#    1070             self.settimeout(timeout)
#
# ~/data/applications/anaconda3/lib/python3.6/ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:
# > /home/dslochower/data/applications/anaconda3/lib/python3.6/ssl.py(689)do_handshake()
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
